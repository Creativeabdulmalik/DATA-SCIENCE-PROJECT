# %% [markdown]
# # ASSIGNMENT_3 ED ANALYSIS(minnesota_birds)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# load the dataset
Minnesota_Birds = pd.read_csv('Minnesota_Birds.csv')
print(Minnesota_Birds.head())

# %%
# information about the dataset
Minnesota_Birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      444 non-null    object
#  1   Scientific Name           444 non-null    object
#  2   Indicator or Other Notes  140 non-null    object
#  3   Category                  444 non-null    object
#  4   State                     45 non-null     object
#  5   Kingdom                   444 non-null    object
#  6   Phylum                    444 non-null    object
#  7   Class                     444 non-null    object
#  8   Order                     444 non-null    object
#  9   Family                    444 non-null    object
#  10  Genus                     444 non-null    object
#  11  Conservation_Status       443 non-null    object
#  12  Length_Min_(cm)           444 non-null    float64
# ...

# %%
# identify the missing values
Minnesota_Birds.isnull().sum()
# Out:
# Name                          0
# Scientific Name               0
# Indicator or Other Notes    304
# Category                      0
# State                       399
# Kingdom                       0
# Phylum                        0
# Class                         0
# Order                         0
# Family                        0
# Genus                         0
# Conservation_Status           1
# Length_Min_(cm)               0
# Length_Max_(cm)               0
# Body_Mass_Min (g)             0
# Body_Mass_Max (g)             0
# Wingspan_Min_(cm)             1
# Wingspan_Max_(cm)             1
# dtype: int64

# %%
# count the number of unique values in each column
missing_values = Minnesota_Birds.isnull().sum()
print(missing_values)
# Out:
# Name                          0
# Scientific Name               0
# Indicator or Other Notes    304
# Category                      0
# State                       399
# Kingdom                       0
# Phylum                        0
# Class                         0
# Order                         0
# Family                        0
# Genus                         0
# Conservation_Status           1
# Length_Min_(cm)               0
# Length_Max_(cm)               0
# Body_Mass_Min (g)             0
# Body_Mass_Max (g)             0
# Wingspan_Min_(cm)             1
# Wingspan_Max_(cm)             1
# dtype: int64

# %%
# count the number of unique values in each column
unique_counts = Minnesota_Birds.nunique()
print(unique_counts)
# Out:
# Name                        444
# Scientific Name             444
# Indicator or Other Notes      7
# Category                     60
# State                         1
# Kingdom                       1
# Phylum                        1
# Class                         1
# Order                        21
# Family                       60
# Genus                       238
# Conservation_Status           6
# Length_Min_(cm)              97
# Length_Max_(cm)             114
# Body_Mass_Min (g)           233
# Body_Mass_Max (g)           271
# Wingspan_Min_(cm)           137
# Wingspan_Max_(cm)           157
# dtype: int64

# %%
Minnesota_Birds.fillna(Minnesota_Birds.mean(numeric_only=True), inplace=True)
# information about the dataset after filling missing values
Minnesota_Birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      444 non-null    object
#  1   Scientific Name           444 non-null    object
#  2   Indicator or Other Notes  140 non-null    object
#  3   Category                  444 non-null    object
#  4   State                     45 non-null     object
#  5   Kingdom                   444 non-null    object
#  6   Phylum                    444 non-null    object
#  7   Class                     444 non-null    object
#  8   Order                     444 non-null    object
#  9   Family                    444 non-null    object
#  10  Genus                     444 non-null    object
#  11  Conservation_Status       443 non-null    object
#  12  Length_Min_(cm)           444 non-null    float64
# ...

# %%
Minnesota_Birds.head()
# Out:
#                            Name         Scientific Name  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#   Indicator or Other Notes                     Category      State   Kingdom  \
# 0                      (A)  Ducks, geese, and waterfowl  Minnesota  Animalia
# 1                      (A)  Ducks, geese, and waterfowl  Minnesota  Animalia
# 2                      NaN  Ducks, geese, and waterfowl  Minnesota  Animalia
# 3                      NaN  Ducks, geese, and waterfowl  Minnesota  Animalia
# 4                      NaN  Ducks, geese, and waterfowl  Minnesota  Animalia
#
#      Phylum Class         Order    Family        Genus Conservation_Status  \
# 0  Chordata  Aves  Anseriformes  Anatidae  Dendrocygna                  LC
# ...

# %%
# check for missing values in the dataset
Minnesota_Birds = Minnesota_Birds
print(df.isnull().sum())
# Out:
# Name                          0
# Scientific Name               0
# Indicator or Other Notes    304
# Category                      0
# State                       399
# Kingdom                       0
# Phylum                        0
# Class                         0
# Order                         0
# Family                        0
# Genus                         0
# Conservation_Status           1
# Length_Min_(cm)               0
# Length_Max_(cm)               0
# Body_Mass_Min (g)             0
# Body_Mass_Max (g)             0
# Wingspan_Min_(cm)             0
# Wingspan_Max_(cm)             0
# dtype: int64

# %%
import seaborn as sns

# Histogram with KDE (smoothed curve)
sns.histplot(data=Minnesota_Birds, x='Length_Min_(cm)', bins=10, kde=True, color='teal')
plt.title('Length_Min_(cm) Distribution with KDE')
plt.xlabel('Length_Min_(cm)')
plt.ylabel('Count')
plt.show()

# %%
# Histogram with KDE (smoothed curve)
sns.histplot(data=Minnesota_Birds, x='Length_Max_(cm)', bins=10, kde=True, color='coral')
plt.title('Length_Max_(cm) Distribution with KDE')
plt.xlabel('Length_Max_(cm)')
plt.ylabel('Count')
plt.show()

# %%
numeric_cols = ['Body_Mass_Min (g)', 'Body_Mass_Max (g)', 'Wingspan_Min_(cm)',
                'Wingspan_Max_(cm)', 'Length_Min_(cm)', 'Length_Max_(cm)'] 

for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=Minnesota_Birds, x=col, bins=15, kde=True, color='coral')
    plt.title(f'{col} Distribution')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.grid(True)
    plt.show()
